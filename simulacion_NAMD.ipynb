# %% [markdown]
# # DINÁMICA MOLECULAR PROTEÍNA-LIGANDO EN NAMD
#
# ## Autores:
#
# ### -Emilio Paredes Solis
# BSc. Ingeniería electrónica, Universidad Peruana de Ciencias Aplicadas-UPC
#
# ### Yaritza Ramirez
# BS. Biotecnología, Universidad Nacional del Santa

# %% [markdown]
# PREVIO: Para dar inicio, debemos verificar que ya tenemos los siguientes archivos
#          - autoionize.tcl
#          - box.tcl
#          - cioinize.tcl
#          - get_drug.tcl
#          - em.namd
#          - make_rest.tcl
#          - mdrun.namd
#          - npt.namd
#          - nvt.namd
#          - rtop.tcl
#          - solvate.tcl
#          - sort_mol2_bonds.pl
#          - top_build.tcl
#          - vector.tcl
#          - carpeta toppar

# %% [markdown]
# ### NOTA: Primero deben descargar la data del PDB Data Bank
# #####  https://www.rcsb.org/    el cristal 4yji en formato PDB
# #### Es importante tomar en cuenta:
# ##### 1.1 Instalar VMD
# ##### 1.2 Instalar Openbabel(opcional)
# ##### 1.3 Instalar NAMD
#
# ##### Finalmente para saber el nombre del ligando abrir el archivo 4yji.pdb con el editor de texto(gedit) y revisar el nombre de la 4ta columna de HETATM y se podrá observar el nombre.

# %% [markdown]
# ## PARTE 1: Generando las Topologías

# %% [markdown]
# Es para combinar el conjunto de todos los átomos con sus respectivos parámetros de interacción

# %%
# %%bash
# gedit get_drug.tcl

# %%
# %%bash
# vmd -dispdev text -e get_drug.tcl

# %% [markdown]
# #### Para tener el archivo en str: i) Abro https://cgenff.umaryland.edu/ , i.1.) Ingreso mi cuenta para poder hacer la conversión, ii) Carga el archivo TYL_fix.mol2, click uploade molecule, iii) Click al archivo que ahora esta en str, copias todo, iv) Abre el terminal vim TYL_fix.str , pegas todo y lo guardas

# %% [markdown]
# ![CGenFF.png](attachment:CGenFF.png)

# %% [markdown]
# ![str.png](attachment:str.png)

# %% [markdown]
# ## PARTE 2: Construcción de la topología drug-protein complex

# %%
# %%bash
# gedit top_build.tcl

# %%
# %%bash
# vmd -dispdev text -e top_build.tcl
# Out:
# Info) VMD for LINUXAMD64, version 1.9.4a12 (December 21, 2017)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 8 CPUs detected.
# Info)   CPU features: SSE2 AVX AVX2 FMA
# Info) Free system memory: 8GB (73%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator:
# Info) [0] GeForce GTX 1050      5 SM_6.1 1.49 GHz, 3.9GB RAM, KTO, AE2, ZCP
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling 1 OptiX shaders on 1 target GPU...
# Info) Dynamically loaded 3 plugins in directory:
# Info) /usr/local/lib/vmd/plugins/LINUXAMD64/molfile
# ...

# %% [markdown]
# ##### Tenemos que verificar si todo lo que se ha generado está bien para ello visualizamos en VMD

# %%
# %%bash
# vmd AAA_TYL.psf AAA_TYL.pdb
# Out:
# Info) VMD for LINUXAMD64, version 1.9.4a12 (December 21, 2017)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 8 CPUs detected.
# Info)   CPU features: SSE2 AVX AVX2 FMA
# Info) Free system memory: 9GB (74%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator:
# Info) [0] GeForce GTX 1050      5 SM_6.1 1.49 GHz, 3.9GB RAM, KTO, AE2, ZCP
# Warning) Detected X11 'Composite' extension: if incorrect display occurs
# Warning) try disabling this X server option.  Most OpenGL drivers
# Warning) disable stereoscopic display when 'Composite' is enabled.
# ...

# %% [markdown]
# ## PARTE 3: Generar moléculas de iones en el sistema

# %%
# %%bash
# gedit cionize.tcl

# %%
# %%bash
# vmd -dispdev text -e cionize.tcl
# Out:
# Info) VMD for LINUXAMD64, version 1.9.4a12 (December 21, 2017)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 8 CPUs detected.
# Info)   CPU features: SSE2 AVX AVX2 FMA
# Info) Free system memory: 9GB (75%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator:
# Info) [0] GeForce GTX 1050      5 SM_6.1 1.49 GHz, 3.9GB RAM, KTO, AE2, ZCP
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling 1 OptiX shaders on 1 target GPU...
# Info) Dynamically loaded 3 plugins in directory:
# Info) /usr/local/lib/vmd/plugins/LINUXAMD64/molfile
# 1.0
# ...

# %%
# %%bash
# gedit rtop.tcl

# %%
# %%bash
# vmd -dispdev text -e rtop.tcl
# Out:
# Info) VMD for LINUXAMD64, version 1.9.4a12 (December 21, 2017)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 8 CPUs detected.
# Info)   CPU features: SSE2 AVX AVX2 FMA
# Info) Free system memory: 9GB (75%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator:
# Info) [0] GeForce GTX 1050      5 SM_6.1 1.49 GHz, 3.9GB RAM, KTO, AE2, ZCP
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling 1 OptiX shaders on 1 target GPU...
# Info) Dynamically loaded 3 plugins in directory:
# Info) /usr/local/lib/vmd/plugins/LINUXAMD64/molfile
# ...

# %% [markdown]
# ### Luego abro el VMD, i) Click en extensiones, tk Console, ii) source box.tcl, iii) source solvate.tcl, iv) quit

# %%
# %%bash
# vmd
# Out:
# Info) VMD for LINUXAMD64, version 1.9.4a12 (December 21, 2017)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 8 CPUs detected.
# Info)   CPU features: SSE2 AVX AVX2 FMA
# Info) Free system memory: 9GB (75%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator:
# Info) [0] GeForce GTX 1050      5 SM_6.1 1.49 GHz, 3.9GB RAM, KTO, AE2, ZCP
# Warning) Detected X11 'Composite' extension: if incorrect display occurs
# Warning) try disabling this X server option.  Most OpenGL drivers
# Warning) disable stereoscopic display when 'Composite' is enabled.
# ...

# %% [markdown]
# ![sol.png](attachment:sol.png)

# %%
# %%bash
# gedit autoionize.tcl

# %%
# %%bash
# vmd -dispdev text -e autoionize.tcl
# Out:
# Info) VMD for LINUXAMD64, version 1.9.4a12 (December 21, 2017)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 8 CPUs detected.
# Info)   CPU features: SSE2 AVX AVX2 FMA
# Info) Free system memory: 8GB (72%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator:
# Info) [0] GeForce GTX 1050      5 SM_6.1 1.49 GHz, 3.9GB RAM, KTO, AE2, ZCP
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling 1 OptiX shaders on 1 target GPU...
# Info) Dynamically loaded 3 plugins in directory:
# Info) /usr/local/lib/vmd/plugins/LINUXAMD64/molfile
# 1.5
# ...

# %%
# %%bash
# gedit vector.tcl

# %%
# %%bash
# vmd -dispdev text -e vector.tcl
# Out:
# Info) VMD for LINUXAMD64, version 1.9.4a12 (December 21, 2017)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 8 CPUs detected.
# Info)   CPU features: SSE2 AVX AVX2 FMA
# Info) Free system memory: 10GB (89%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator:
# Info) [0] GeForce GTX 1050      5 SM_6.1 1.49 GHz, 3.9GB RAM, KTO, AE2, ZCP
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling 1 OptiX shaders on 1 target GPU...
# Info) Dynamically loaded 3 plugins in directory:
# Info) /usr/local/lib/vmd/plugins/LINUXAMD64/molfile
# ...

# %%
# %%bash
# gedit cellvector.dat

# %% [markdown]
# ## PARTE 4: Minimización de energía

# %% [markdown]
# * Debemos copiar toda la información que se encuentra en el cellvector.dat, porque vamos a editar en el archivo em.namd

# %%
# %%bash
# gedit em.namd

# %%
# %%bash
# namd2 +idlepoll +p8 +devices 0 em.namd >& em.log

# %%
# %%bash
# tail -90f em.log
# Out:
# Process is interrupted.

# %% [markdown]
# ![em.png](attachment:em.png)

# %% [markdown]
# ## Parte 5: Equilibración
# ### Parte 5.1: Restricción del ligando y la proteina

# %%
# %%bash
# gedit make_rest.tcl

# %%
# %%bash
# vmd -dispdev text -e make_rest.tcl
# Out:
# Info) VMD for LINUXAMD64, version 1.9.4a12 (December 21, 2017)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 8 CPUs detected.
# Info)   CPU features: SSE2 AVX AVX2 FMA
# Info) Free system memory: 10GB (86%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator:
# Info) [0] GeForce GTX 1050      5 SM_6.1 1.49 GHz, 3.9GB RAM, KTO, AE2, ZCP
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling 1 OptiX shaders on 1 target GPU...
# Info) Dynamically loaded 3 plugins in directory:
# Info) /usr/local/lib/vmd/plugins/LINUXAMD64/molfile
# ...

# %% [markdown]
# ### Parte5.2: Termostato

# %%
# %%bash
# gedit nvt.namd

# %%
# %%bash
# namd2 +idlepoll +p8 +devices 0 nvt.namd >& heat.log

# %%
# %%bash
# tail -90f heat.log

# %% [markdown]
# ![nv.png](attachment:nv.png)

# %% [markdown]
# Me va a mostrar como se va incrementando el calentamiento del sistema.
# ### Parte 5.3: Presión

# %%
# %%bash
# gedit npt.namd

# %%
# %%bash
# namd2 +idlepoll +p8 +devices 0 npt.namd >& relax.log

# %%
# %%bash
# tail -90f heat.log | grep TCL

# %% [markdown]
# ## PARTE 6: Simulación

# %%
# %%bash
# gedit mdrun.namd

# %%
# %%bash
# namd2 +idlepoll +p8 +devices 0 mdrun.namd >& md.log &

# %%
# %%bash
# tail -90f md.log
